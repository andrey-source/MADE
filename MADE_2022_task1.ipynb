# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split

df = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# del df['5'] 

x_train, x_valid, y_train, y_valid = train_test_split(df.iloc[:, :-1].values, df.iloc[:, -1].values, 
                                                      stratify=df.iloc[:, -1].values, random_state=42)
df.iloc[df.target.values == 1, :].hist(figsize=(16, 12), bins=40)
plt.show()

# %%
df.iloc[df.target.values == 0, :].hist(figsize=(16, 12), bins=40)
plt.show()

# %%
df_test.hist(figsize=(16, 12), bins=15)
plt.show()

# %%
x_train.shape[1]
# Out:
# 31

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score



def test_features(x_train, x_valid, y_train, y_valid, verbose=True):
    results_F1 = {'train': [], 'valid': []}
    results_auc = {'train': [], 'valid': []}
    model = Pipeline([
        ('SS', StandardScaler()),
        ('SVC', SVC(kernel='rbf', C=1, probability=True))
    ])
    for n_feat in tqdm(range(1, x_train.shape[1])):
        model.fit(x_train[:, :n_feat], y_train)
        pred_train = model.predict(x_train[:, :n_feat])
        pred_valid = model.predict(x_valid[:, :n_feat])
        results_F1['train'].append(f1_score(y_train, pred_train))
        results_F1['valid'].append(f1_score(y_valid, pred_valid))
        if verbose:
            print(f'n_feat: {n_feat}')
            print(f'train: {f1_score(y_train, pred_train)}')
            print(f'valid: {f1_score(y_valid, pred_valid)}')
            print(' ')
    return results_F1

# %%
results_F1 = test_features(x_train, x_valid, y_train, y_valid, verbose=False)
plt.grid()
plt.plot(results_F1['train'], label='train')
plt.plot(results_F1['valid'], label='valid')
plt.legend()
plt.show()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=30.0), HTML(value='')))

# %%
plt.scatter(x_train[y_train==0, 5], x_train[y_train==0, 6], label = '1', alpha=0.3)
plt.scatter(x_train[y_train==1, 5], x_train[y_train==1, 6], label = '0', alpha=0.3)
plt.legend()
plt.show()

# %%
df = pd.read_csv('train.csv')
del df['5']
x_train, x_valid, y_train, y_valid = train_test_split(df.iloc[:, :-1].values, df.iloc[:, -1].values, 
                                                      stratify=df.iloc[:, -1].values, random_state=42)
results_F1 = test_features(x_train, x_valid, y_train, y_valid, verbose=False)
plt.grid()
plt.plot(results_F1['train'], label='train')
plt.plot(results_F1['valid'], label='valid')
plt.legend()
plt.show()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=29.0), HTML(value='')))

# %%
# функция жадного отбора признаков ()

# %%
# from sklearn.model_selection import cross_val_score
# from catboost import Pool, CatBoostClassifier
# import copy

# def feature_select(x, y, model, cv=5, verbose=True):
#     features = [*range(x.shape[1])]
#     best_score = cross_val_score(model, x, y, cv=cv, scoring='f1').mean() 
#     print(f"best score: {best_score}")
#     exit = True
#     while exit:
#         exit = False
#         for i in features:
#             copy_features = copy.copy(features)
#             copy_features.remove(i)
#             score = cross_val_score(model, x[:, copy_features], y, cv=cv, scoring='f1').mean()
#             if verbose:
#                 print(score, i)
#             if best_score < score:
#                 exit = True
#                 features = copy_features
#                 best_score = score
#                 print(f'best_score: {best_score}')
#                 break
#     return features


# model = CatBoostClassifier(n_estimators=1000,
#                            depth=6,
#                            learning_rate=0.1, 
#                            rsm=0.4,
# #                            bagging_temperature = 0.3,
#                            l2_leaf_reg = 100,
#                            random_state=42,     
#                            auto_class_weights='Balanced',
#                            eval_metric='F1',
#                            verbose=False,
#                           )

# f = feature_select(df.iloc[:, :-1].values, df.iloc[:, -1].values, model, verbose=False)

# %%
df.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col0,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row1_col1,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row2_col2,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row3_col3,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row4_col4,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row5_col5,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row6_col6,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row7_col7,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row8_col8,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row9_col9,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row10_col10,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row11_col11,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row12_col12,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row13_col13,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row14_col14,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row15_col15,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row16_col16,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row17_col17,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row18_col18,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row19_col19,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row20_col20,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row21_col21,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row22_col22,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row23_col23,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row24_col24,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row25_col25,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row26_col26,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row27_col27,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row28_col28,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row29_col29,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row30_col30{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col1,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col24,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row5_col21,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row9_col3,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row16_col2,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row17_col21{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col2,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col3,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col8,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row2_col16,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row5_col1,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row7_col17,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row9_col8,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row16_col7,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row21_col3,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row29_col13{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col4,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col14,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col23,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row1_col13,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row1_col16,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row3_col22,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row5_col28,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row6_col23,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row8_col27,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row13_col1,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row14_col0,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row14_col7,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row14_col9,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row14_col18,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row20_col21,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row21_col8,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row21_col20,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row22_col3,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row23_col6,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row23_col10,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row23_col12,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row23_col17,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row26_col11,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row26_col24,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row26_col25,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row26_col29,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row27_col16,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row27_col30,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row28_col5,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row29_col2,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row29_col10,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row29_col15,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row29_col19,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row29_col26{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col5,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row8_col7,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row21_col23{
#             background-color:  #a2bcda;
#             color:  #000000;
#         }#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col6,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row2_col21,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row5_col11,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row5_col27,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row6_col18,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row11_col29,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row15_col0,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row18_col19,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row29_col14,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row30_col3,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row30_col21{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col7,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row1_col28,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row8_col15,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row11_col0,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row13_col15,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row13_col20,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row17_col11,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row17_col19,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row18_col24,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row19_col0,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row21_col10,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row29_col11,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row30_col11,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row30_col23,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row30_col26,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row30_col28{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col9{
#             background-color:  #83afd3;
#             color:  #000000;
#         }#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col10,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row3_col13,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row11_col25,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row15_col26,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row18_col1,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row20_col11,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row22_col19,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row26_col21{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col11,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row1_col29,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row4_col6,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row11_col17,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row16_col1,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row17_col16,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row25_col16,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row27_col2,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row28_col4{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col12,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row2_col23,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row3_col24,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row10_col6,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row14_col1,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row14_col8,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row17_col6,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row17_col25,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row20_col1,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row23_col28,#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row29_col4{
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }#T_15477097_20d6_11ed_a8f2_1c1bb5d460e7row0_col13,#T_15477097_20

# %%
scaler = StandardScaler()
x_st = scaler.fit_transform(df.iloc[:, :-1].values)
u, s, v = np.linalg.svd(x_st.T @ x_st)
print(s/s.sum() * 100)
plt.grid()
plt.plot(s/s.sum()*100)
plt.show()
# Out:
# [12.90873387  9.69141443  9.44677949  8.33858477  6.58719416  6.3241478
#   5.79495912  4.71936222  4.38723832  4.12088777  3.58662159  3.37980168
#   3.21276167  2.98053072  2.61110965  2.35324522  2.00334199  1.87355252
#   1.67311933  1.58570882  0.33870425  0.32402577  0.29514806  0.2817616
#   0.24890909  0.23931503  0.20978603  0.19947627  0.14857273  0.13520599]

# %%
from sklearn.mixture import GaussianMixture
from sklearn.manifold import TSNE
import matplotlib.colors as colors
colors_list = list(colors._colors_full_map.values())  # список цветов


tsne = Pipeline([
    ('SS', StandardScaler()), # 50, 70, 105, 115
    ('TSNE', TSNE(n_components=2, perplexity=115, random_state=42, learning_rate = 100,
                  metric='mahalanobis', init='pca', square_distances=True, 
                 ))
])

cluster_model = Pipeline([
    ('SS', StandardScaler()),
    ('GM', GaussianMixture(n_components=4, random_state=42, n_init=10))
])

X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

labels = cluster_model.fit_predict(X)

x_tsne = tsne.fit_transform(X)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize = (16, 8), sharey=True)
for i in np.unique(labels):
    ax1.scatter(x_tsne[i == labels, 0], x_tsne[i == labels, 1], cmap=colors_list[i], alpha=0.1, label=i)
for i in np.unique(y_train):
    ax2.scatter(x_tsne[i == y, 0], x_tsne[i == y, 1], cmap=colors_list[i], alpha=0.1, label=i)
ax1.legend()
ax2.legend()
ax1.grid()
ax2.grid()
plt.show()

# %%
from sklearn.metrics import silhouette_score
# from sklearn.cluster import KMeans

def find_n_clusters(X, n=10):
    scores = []
    for i in tqdm(range(2, n)):
        cluster_model = Pipeline([
            ('SS', StandardScaler()),
            ('GM', GaussianMixture(n_components=i, random_state=42, n_init=10))
        ])
        labels = cluster_model.fit_predict(X)
        scores.append(silhouette_score(X, labels, metric='mahalanobis', random_state=42))
    return scores

scores = find_n_clusters(X, 10)
plt.plot(range(2, len(scores)+2), scores)
plt.grid()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %% [markdown]
# Удаляю наблюдения выборсы

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.mixture import GaussianMixture

svc = Pipeline([
    ('SS', StandardScaler()),
    ('SVC', SVC(kernel='rbf', C=3, probability=True, random_state=42, class_weight='balanced'))
])
cluster_model = Pipeline([
    ('SS', StandardScaler()),
    ('GM', GaussianMixture(n_components=4, random_state=42, n_init=10))
])


cluster_model.fit(df.iloc[:, :-1])
proba = cluster_model.predict_proba(df.iloc[:, :-1])
X = np.hstack([df.iloc[:, :-1], proba])
y = df.iloc[:, -1]
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
pbar = tqdm(iter(skf.split(X, y)), leave = True, total=5) 
noises = []
for train_index, valid_index in pbar:
    svc.fit(X[train_index], y[train_index])
    pred_proba = svc.predict_proba(X[valid_index])[:, 0]
    pred = svc.predict(X[valid_index])
    mask1 = pred != y[valid_index]
    mask2 = (pred_proba > 0.7) + (pred_proba < 0.3)
    mask = mask1 & mask2
    noises += valid_index[mask].tolist()
    
df.drop(index=noises, axis=0, inplace=True)
df.reset_index()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
#       index         0          1         2         3          4         6  \
# 0         0 -6.130724   7.429628  3.651437 -1.950971  -3.384415 -3.077774
# 1         1  5.161836  -6.514011 -7.474612 -4.544336 -13.081404 -1.094672
# 2         2 -2.971550 -21.508184 -1.125457  1.524129   3.027444  1.551050
# 3         3  6.724419   0.566489  0.509764 -4.524162  10.367236  0.741790
# 4         4 -2.213659  -4.678213 -0.135845  2.375933   0.916649 -0.353265
# ...     ...       ...        ...       ...       ...        ...       ...
# 6867   6957 -0.896727  -1.081807 -0.992381  0.147425   5.941532  2.117062
# 6868   6958  1.554111   2.018845 -2.550991 -2.049014   0.931923  2.260598
# 6869   6960 -2.348591  -8.263995 -0.318484  1.851011  -4.880470 -4.348202
# 6870   6961  5.481595   4.899412 -0.421851  4.639328 -20.671090 -3.838050
# 6871   6962  0.939142  -0.354990 -5.475815 -0.108931 -14.824023  1.245086
#
#              7         8          9  ...        22         23         24  \
# 0    -2.619091  5.128201   1.228476  ...  0.392978   4.920467  16.610460
# 1    -1.253545 -2.955342 -10.958200  ... -4.840233  -0.514308   4.613289
# 2     1.512075 -1.955564   3.683893  ... -0.385303   2.647917  -2.200556
# 3    -2.077787 -2.912744  -4.040637  ...  4.731346  15.378418 -14.031666
# 4    -0.220609 -3.416823  -5.964181  ...  1.598330  -4.996614   4.504269
# ...        ...       ...        ...  ...       ...        ...        ...
# 6867  1.254686  0.035905   1.025841  ...  2.404494   5.175765   5.075319
# 6868  0.907393  0.559868  -0.366525  ... -2.078071   2.774934  -5.819371
# 6869  2.937274 -3.067852  -0.173702  ...  0.819033   0.794195   9.353774
# 6870  0.622003  1.548813  -8.847505  ...  1.697137  -8.315975   6.149865
# 6871  3.083056  0.605012  -6.443162  ...  1.078489   4.810056  -3.133966
#
#             25        26         27        28         29         30  target
# 0    -2.430804 -1.405573  18.610209 -4.140715   6.027816 -20.288145       0
# 1     2.391302 -4.795664   4.208278 -2.017168  -8.510424  10.806639       0
# 2     1.058671  1.076312  -7.802389 -7.553953   0.636639  14.274950       0
# 3     2.659410  5.123620  -8.500321  3.417960 -14.798490  -6.132800       1
# 4     1.918961 -2.076223   0.154039 -2.016779  10.803205   5.942927       0
# ...        ...       ...        ...       ...        ...        ...     ...
# 6867 -2.230586  1.850830  -4.405087  3.328801  -1.303900  -4.153117       1
# 6868 -1.397282  0.629832  -1.098601 -7.498520  -7.752161  12.691050       0
# 6869 -1.841798 -1.116251   6.708149 -1.841971   5.747190  -7.608288       0
# 6870  1.437154 -7.284716   4.566744 -0.908937  11.555781   2.889093       0
# 6871 -1.943968 -5.005418   7.176940 -1.482443  -3.219556   0.996970       1
#
# [6872 rows x 32 columns]

# %%
x_train, x_valid, y_train, y_valid = train_test_split(df.iloc[:, :-1].values, df.iloc[:, -1].values, 
                                                      stratify=df.iloc[:, -1].values, random_state=42)

cl = Pipeline([
    ('SS', StandardScaler()),
    ('GM', GaussianMixture(n_components=4, random_state=42, n_init=10))
])



cl.fit(x_train)
train_proba = cl.predict_proba(x_train)
valid_proba = cl.predict_proba(x_valid)
x_train_ = np.hstack([x_train, train_proba])
x_valid_ = np.hstack([x_valid, valid_proba])




model = Pipeline([
    ('SS', StandardScaler()),
    ('SVC', SVC(kernel='rbf', C=1, degree=3, probability=True, random_state=42, class_weight='balanced'))
])

model.fit(x_train_, y_train)
pred_train = model.predict(x_train_)
pred_valid = model.predict(x_valid_)
print(f'train: {f1_score(y_train, pred_train)}')
print(f'valid: {f1_score(y_valid, pred_valid)}')

# x_train['label'] = train_labels
# x_valid['label'] = valid_labels
# Out:
# train: 0.9952283571915473
# valid: 0.9979508196721312

# %%
# from sklearn.model_selection import StratifiedKFold



# def cross_val_score(cluster_model, model, X, y, n_splits=10): 
#     skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
#     f1_train = []
#     f1_valid = []
#     pbar = tqdm(iter(skf.split(X, y)), leave = True, total=n_splits) 
    
#     for i, (train_index, valid_index) in enumerate(pbar):
#         cluster_model.fit(X[train_index])
#         pred_cluster_proba_train = cluster_model.predict_proba(X[train_index])
#         pred_cluster_proba_valid = cluster_model.predict_proba(X[valid_index])
#         x_train = np.hstack([X[train_index], pred_cluster_proba_train])
#         x_valid = np.hstack([X[valid_index], pred_cluster_proba_valid])
#         model.fit(x_train, y[train_index])
#         pred_train = model.predict(x_train)
#         pred_valid = model.predict(x_valid)
#         f1_train.append(f1_score(pred_train, y[train_index]))
#         f1_valid.append(f1_score(pred_valid, y[valid_index]))
        
        
#     return f1_train, f1_valid

# %% [markdown]
#  Использую для прогноза следующие признаки:
#  * исходные признаки
#  * апостериарные вероятности ЕМ кластеризации
#  * прогнозы модели по исходным признакам (бью на 5 частей на 4 учу для пятой предсказываю признаки) качество не улучшало

# %%
from sklearn.model_selection import StratifiedKFold



def cross_val_score(cluster_model, feature_model, cls_model, X, y, n_splits=10): 
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    sub_skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    
    f1_train = []
    f1_valid = []
    pbar = tqdm(iter(skf.split(X, y)), leave = True, total=n_splits) 
    for train_index, valid_index in pbar:
        cluster_model.fit(X[train_index])
        pred_cluster_proba_train = cluster_model.predict_proba(X[train_index])
        pred_cluster_proba_valid = cluster_model.predict_proba(X[valid_index])
        
        model_features = []
        
        sub_pbar = tqdm(iter(sub_skf.split(X[train_index], y[train_index])), leave = True, total=n_splits)
        for sub_train, sub_valid in sub_pbar:
            feature_model.fit(X[train_index][sub_train], y[train_index][sub_train])
            model_features.append(feature_model.predict_proba(X[train_index][sub_valid]))
        feature_model.fit(X[train_index], y[train_index])
        pred_feature_proba_train = np.vstack(model_features)
        pred_feature_proba_valid = feature_model.predict_proba(X[valid_index])
        
        x_train = np.hstack([pred_feature_proba_train, pred_cluster_proba_train, X[train_index]])
        x_valid = np.hstack([pred_feature_proba_valid, pred_cluster_proba_valid, X[valid_index]])
        model.fit(x_train, y[train_index])
        pred_train = model.predict(x_train)
        pred_valid = model.predict(x_valid)
        f1_train.append(f1_score(pred_train, y[train_index]))
        f1_valid.append(f1_score(pred_valid, y[valid_index]))
        
    return f1_train, f1_valid

# %%
from catboost import CatBoostClassifier, Pool
from xgboost import XGBClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture, BayesianGaussianMixture



cluster_model = Pipeline([
    ('SS', StandardScaler()),
#     ('pca', PCA(n_components=0.99, random_state=42)),  # хуже работает
#     ('GM', BayesianGaussianMixture(n_components=5, random_state=42, n_init=10))
    ('GM', GaussianMixture(n_components=4, random_state=42, n_init=10))
])
 
svc = Pipeline([
    ('SS', StandardScaler()),
#     ('pca', PCA(n_components=20, random_state=42)),  # хуже работает
    ('SVC', SVC(kernel='rbf', C=3, probability=True, random_state=42, class_weight='balanced'))
])


cat = CatBoostClassifier(
    n_estimators=400,
    depth=4,
    learning_rate=0.2,
    rsm=0.5,
    random_state=42, 
    auto_class_weights='Balanced',
#     auto_class_weights='SqrtBalanced',
    l2_leaf_reg = 10,
    verbose=False,
    eval_metric='F1'
)


f1_train, f1_valid = cross_val_score(
    cluster_model, cat, svc, df.iloc[:, :-1].values, df.iloc[:, -1].values, n_splits=10)

print('train: ', sum(f1_train) / len(f1_train))
print('valid: ', sum(f1_valid) / len(f1_valid))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# train:  0.9978995487197683
# valid:  0.9948835252114229

# %% [markdown]
# Быстрая проверка без ансамблирования (+- тоже самое)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(df.iloc[:, :-1].values, df.iloc[:, -1].values, 
                                                      stratify=df.iloc[:, -1].values, random_state=42)

cl = Pipeline([
    ('SS', StandardScaler()),
    ('GM', GaussianMixture(n_components=4, random_state=42, n_init=10))
])



cl.fit(x_train)
train_proba = cl.predict_proba(x_train)
valid_proba = cl.predict_proba(x_valid)
x_train_ = np.hstack([x_train, train_proba])
x_valid_ = np.hstack([x_valid, valid_proba])

train_pool = Pool(x_train_, y_train)
valid_pool = Pool(x_valid_, y_valid)
cat = CatBoostClassifier(
    n_estimators=400,
    depth=4,
    learning_rate=0.1,
    rsm=0.5,
    
    random_state=42, 
    auto_class_weights='Balanced',
    l2_leaf_reg = 100,
    verbose=True,
    eval_metric='F1'
)

cat.fit(train_pool, eval_set=valid_pool)
pred_train = cat.predict(train_pool)
pred_valid = cat.predict(valid_pool)
train_proba = cat.predict_proba(train_pool)
valid_prona = cat.predict_proba(valid_pool)

print(f'train: {f1_score(y_train, pred_train)}')
print(f'valid: {f1_score(y_valid, pred_valid)}')
# Out:
# 0:	learn: 0.9878519	test: 0.9861922	best: 0.9861922 (0)	total: 25.3ms	remaining: 10.1s
# 1:	learn: 0.9891005	test: 0.9897246	best: 0.9897246 (1)	total: 36.3ms	remaining: 7.22s
# 2:	learn: 0.9915674	test: 0.9886246	best: 0.9897246 (1)	total: 46.8ms	remaining: 6.19s
# 3:	learn: 0.9915674	test: 0.9886246	best: 0.9897246 (1)	total: 63.6ms	remaining: 6.3s
# 4:	learn: 0.9937260	test: 0.9944550	best: 0.9944550 (4)	total: 70ms	remaining: 5.53s
# 5:	learn: 0.9939347	test: 0.9944550	best: 0.9944550 (4)	total: 75.9ms	remaining: 4.98s
# 117:	learn: 0.9979635	test: 0.9971629	best: 0.9985702 (7)	total: 515ms	remaining: 1.23s
# 118:	learn: 0.9979635	test: 0.9971629	best: 0.9985702 (7)	total: 518ms	remaining: 1.22s
# 119:	learn: 0.9979635	test: 0.9971629	best: 0.9985702 (7)	total: 522ms	remaining: 1.22s
# 120:	learn: 0.9979635	test: 0.9971629	best: 0.9985702 (7)	total: 526ms	remaining: 1.21s
# 121:	learn: 0.9979635	test: 0.9971629	best: 0.9985702 (7)	total: 529ms	remaining: 1.21s
# 122:	learn: 0.9979635	test: 0.9971629	best: 0.9985702 (7)	total: 533ms	remaining: 1.2s
# 123:	learn: 0.9979635	test: 0.9971629	best: 0.9985702 (7)	total: 536ms	remaining: 1.19s
# 124:	learn: 0.9979635	test: 0.9971629	best: 0.9985702 (7)	total: 540ms	remaining: 1.19s
# 125:	learn: 0.9980987	test: 0.9971629	best: 0.9985702 (7)	total: 543ms	remaining: 1.18s
# 126:	learn: 0.9983049	test: 0.9971629	best: 0.9985702 (7)	total: 547ms	remaining: 1.18s
# 127:	learn: 0.9983049	test: 0.9971629	best: 0.9985702 (7)	total: 550ms	remaining: 1.17s
# 128:	learn: 0.9984401	test: 0.9971629	best: 0.9985702 (7)	total: 554ms	remaining: 1.16s
# 129:	learn: 0.9984401	test: 0.9971629	best: 0.9985702 (7)	total: 558ms	remaining: 1.16s
# 130:	learn: 0.9984401	test: 0.9971629	best: 0.9985702 (7)	total: 562ms	remaining: 1.15s
# 131:	learn: 0.9984401	test: 0.9971629	best: 0.9985702 (7)	total: 566ms	remaining: 1.15s
# 132:	learn: 0.9987813	test: 0.9975672	best: 0.9985702 (7)	total: 571ms	remaining: 1.15s
# 133:	learn: 0.9987813	test: 0.9975672	best: 0.9985702 (7)	total: 575ms	remaining: 1.14s
# 134:	learn: 0.9987813	test: 0.9975672	best: 0.9985702 (7)	total: 579ms	remaining: 1.14s
# 135:	learn: 0.9987813	test: 0.9975672	best: 0.9985702 (7)	total: 582ms	remaining: 1.13s
# 136:	learn: 0.9987813	test: 0.9975672	best: 0.9985702 (7)	total: 587ms	remaining: 1.13s
# 137:	learn: 0.9987813	test: 0.9975672	best: 0.9985702 (7)	total: 592ms	remaining: 1.12s
# 138:	learn: 0.9987813	test: 0.9975672	best: 0.9985702 (7)	total: 596ms	remaining: 1.12s
# 139:	learn: 0.9989166	test: 0.9975672	best: 0.9985702 (7)	total: 600ms	remaining: 1.11s
# 140:	learn: 0.9989166	test: 0.9975672	best: 0.9985702 (7)	total: 606ms	remaining: 1.11s
# 141:	learn: 0.9987813	test: 0.9975672	best: 0.9985702 (7)	total: 609ms	remaining: 1.11s
# 142:	learn: 0.9990519	test: 0.9975672	best: 0.9985702 (7)	total: 613ms	remaining: 1.1s
# 143:	learn: 0.9990519	test: 0.9975672	best: 0.9985702 (7)	total: 617ms	remaining: 1.1s
	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 945ms	remaining: 706ms
# 229:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 948ms	remaining: 701ms
# 230:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 952ms	remaining: 696ms
# 231:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 955ms	remaining: 692ms
# 232:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 959ms	remaining: 687ms
# 233:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 962ms	remaining: 683ms
# 234:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 966ms	remaining: 678ms
# 235:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 969ms	remaining: 673ms
# 236:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 973ms	remaining: 669ms
# 237:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 976ms	remaining: 664ms
# 238:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 979ms	remaining: 660ms
# 239:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 983ms	remaining: 655ms
# 240:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 986ms	remaining: 651ms
# 241:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 990ms	remaining: 646ms
# 242:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 993ms	remaining: 642ms
# 243:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 996ms	remaining: 637ms
# 244:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1000ms	remaining: 633ms
# 245:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.01s	remaining: 636ms
# 246:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.02s	remaining: 632ms
# 247:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.02s	remaining: 628ms
# 248:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.03s	remaining: 624ms
# 249:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.03s	remaining: 620ms
# 250:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.04s	remaining: 615ms
# 251:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.04s	remaining: 610ms
# 252:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.04s	remaining: 606ms
# 253:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.06s	remaining: 608ms
# 254:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.06s	remaining: 603ms
# 255:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.06s	remaining: 598ms
# 256:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.06s	remaining: 593ms
# 257:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.07s	remaining: 589ms
# 258:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.07s	remaining: 584ms
# 259:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.07s	remaining: 579ms
# 260:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.08s	remaining: 574ms
# 261:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.08s	remaining: 570ms
# 262:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.08s	remaining: 565ms
# 263:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.09s	remaining: 561ms
# 264:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.09s	remaining: 556ms
# 265:	learn: 0.9995934	test: 0.9965437	best: 0.9985702 (7)	total: 1.09s	remaining: 551ms
# 266:	learn: 0.9997289	test: 0.9965437	best: 0.9985702 (7)	total: 1.1s	remaining: 547ms
# 267:	learn: 0.9997289	test: 0.9965437	best: 0.9985702 (7)	total: 1.1s	remaining: 542ms
# 268:	learn: 0.9997289	test: 0.9965437	best: 0.9985702 (7)	total: 1.1s	remaining: 537ms
# 269:	learn: 0.9997289	test: 0.9965437	best: 0.9985702 (7)	total: 1.11s	remaining: 533ms
# 270:	learn: 0.9997289	test: 0.9965437	best: 0.9985702 (7)	total: 1.11s	remaining: 528ms
# 271:	learn: 0.9997289	test: 0.9965437	best: 0.9985702 (7)	total: 1.11s	remaining: 524ms
# 272:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.12s	remaining: 520ms
# 273:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.12s	remaining: 515ms
# 274:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.12s	remaining: 511ms
# 275:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.13s	remaining: 506ms
# 276:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.13s	remaining: 502ms
# 277:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.13s	remaining: 498ms
# 278:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.14s	remaining: 493ms
# 279:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.14s	remaining: 489ms
# 280:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.14s	remaining: 485ms
# 281:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.15s	remaining: 480ms
# 282:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.15s	remaining: 476ms
# 283:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.15s	remaining: 472ms
# 284:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.16s	remaining: 467ms
# 285:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.16s	remaining: 463ms
# 286:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.19s	remaining: 468ms
# 287:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.19s	remaining: 465ms
# 288:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.2s	remaining: 461ms
# 289:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.21s	remaining: 458ms
# 290:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.22s	remaining: 456ms
# 291:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.22s	remaining: 452ms
# 292:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.23s	remaining: 451ms
# 293:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.24s	remaining: 447ms
# 294:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1.25s	remaining: 443ms
# 295:	learn: 0.9998644	test: 0.9965437	best: 0.9985702 (7)	total: 1
	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.59s	remaining: 96.9ms
# 377:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.59s	remaining: 92.6ms
# 378:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.59s	remaining: 88.4ms
# 379:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.6s	remaining: 84.1ms
# 380:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.6s	remaining: 79.9ms
# 381:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.6s	remaining: 75.6ms
# 382:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.61s	remaining: 71.4ms
# 383:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.61s	remaining: 67.1ms
# 384:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.61s	remaining: 62.9ms
# 385:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.62s	remaining: 58.7ms
# 386:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.62s	remaining: 54.5ms
# 387:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.62s	remaining: 50.3ms
# 388:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.63s	remaining: 46ms
# 389:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.63s	remaining: 41.8ms
# 390:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.63s	remaining: 37.6ms
# 391:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.64s	remaining: 33.4ms
# 392:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.64s	remaining: 29.2ms
# 393:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.64s	remaining: 25ms
# 394:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.65s	remaining: 20.9ms
# 395:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.65s	remaining: 16.7ms
# 396:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.65s	remaining: 12.5ms
# 397:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.66s	remaining: 8.32ms
# 398:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.66s	remaining: 4.16ms
# 399:	learn: 0.9998644	test: 0.9955181	best: 0.9985702 (7)	total: 1.66s	remaining: 0us
#
# bestTest = 0.998570177
# bestIteration = 7
#
# Shrink model to first 8 iterations.
# train: 0.9928692699490663
# valid: 0.9979550102249489

# %%
def predict(cluster_model, feature_model, cls_model, X, y, X_test, n_splits=10): 
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)        
    pbar = tqdm(iter(skf.split(X, y)), leave = True, total=n_splits)    
    x_train = []
    y_train = []
    pred_feature_proba_train = []
    for train_index, valid_index in pbar:
        x_train.append(X[valid_index])
        y_train.append(y[valid_index].reshape(-1, 1))
        feature_model.fit(X[train_index], y[train_index])
        pred_feature_proba_train.append(feature_model.predict_proba(X[valid_index]))
    x_train = np.vstack(x_train)
    pred_feature_proba_train = np.vstack(pred_feature_proba_train)
    y_train = np.vstack(y_train).reshape(-1)
    cluster_model.fit(x_train)
    feature_model.fit(x_train, y_train)
    pred_cluster_proba_train = cluster_model.predict_proba(x_train)
    x_train = np.hstack([pred_feature_proba_train, pred_cluster_proba_train, x_train])
    pred_feature_proba_test = feature_model.predict_proba(X_test)
    pred_cluster_proba_test = cluster_model.predict_proba(X_test)
    x_test = np.hstack([pred_feature_proba_test, pred_cluster_proba_test, X_test])
    cls_model.fit(x_train, y_train)
    pred_test = cls_model.predict(x_test)  
    return pred_test

# %%
df_test = pd.read_csv('test.csv')
del df_test['5']


cat = CatBoostClassifier(
    n_estimators=400,
    depth=4,
    learning_rate=0.1,
    rsm=0.5,
    
    random_state=42, 
    auto_class_weights='Balanced',
    l2_leaf_reg = 100,
    verbose=False,
    eval_metric='F1'
)

cat1 = CatBoostClassifier(
    n_estimators=8,
    depth=4,
    learning_rate=0.1,
    rsm=0.5,
    
    random_state=42, 
    auto_class_weights='Balanced',
    l2_leaf_reg = 100,
    verbose=False,
    eval_metric='F1'
)

pred_test = predict(cluster_model, cat, cat1, df.iloc[:, :-1].values, 
                    df.iloc[:, -1].values, df_test.values, n_splits=10)

submit = pd.read_csv('sample_submission.csv')
submit.target = pred_test

submit.to_csv('f7.csv', index=False)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
